# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OnlineRetail.csv',encoding='unicode_escape') #unicode_escape for unknown language escape
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.sort_values(by='InvoiceDate', ascending=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 332571    566079     22923  FRIDGE MAGNETS LES ENFANTS ASSORTED        24
# 332544    566079     23403        LETTER HOLDER HOME SWEET HOME         4
# 332551    566079     22396        MAGNETS PACK OF 4 RETRO PHOTO        24
# 332550    566079     22400    MAGNETS PACK OF 4 HOME SWEET HOME        24
# 332549    566079     20838        FRENCH LATTICE CUSHION COVER         12
# ...          ...       ...                                  ...       ...
# 50831     540561     22743   MAKE YOUR OWN FLOWERPOWER CARD KIT         6
# 50809     540561     22343       PARTY PIZZA DISH RED RETROSPOT        24
# 50808     540560     21589                                  NaN       -14
# 50807    C540559     21888                            BINGO SET        -4
# 50806     540558     21258                                    ?       -29
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
current_date = pd.to_datetime('01-01-2012')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
max_date = df.groupby(['CustomerID']).max()[['InvoiceDate']]
max_date
# Out:
#                    InvoiceDate
# CustomerID
# 12346.0    2011-01-18 10:17:00
# 12347.0    2011-12-07 15:52:00
# 12348.0    2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00
# ...                        ...
# 18280.0    2011-03-07 09:52:00
# 18281.0    2011-06-12 10:53:00
# 18282.0    2011-12-02 11:43:00
# 18283.0    2011-12-06 12:02:00
# 18287.0    2011-10-28 09:29:00
#
# [4372 rows x 1 columns]

# %%
max_date['InvoiceAge'] = (current_date - max_date['InvoiceDate']).dt.days
max_date
# Out:
#                    InvoiceDate  InvoiceAge
# CustomerID
# 12346.0    2011-01-18 10:17:00         347
# 12347.0    2011-12-07 15:52:00          24
# 12348.0    2011-09-25 13:13:00          97
# 12349.0    2011-11-21 09:51:00          40
# 12350.0    2011-02-02 16:01:00         332
# ...                        ...         ...
# 18280.0    2011-03-07 09:52:00         299
# 18281.0    2011-06-12 10:53:00         202
# 18282.0    2011-12-02 11:43:00          29
# 18283.0    2011-12-06 12:02:00          25
# 18287.0    2011-10-28 09:29:00          64
#
# [4372 rows x 2 columns]

# %%
#Last shopping date of a customer
recency=max_date.drop('InvoiceDate',axis=1)
recency
# Out:
#             InvoiceAge
# CustomerID
# 12346.0            347
# 12347.0             24
# 12348.0             97
# 12349.0             40
# 12350.0            332
# ...                ...
# 18280.0            299
# 18281.0            202
# 18282.0             29
# 18283.0             25
# 18287.0             64
#
# [4372 rows x 1 columns]

# %%
frequency=df.drop_duplicates('InvoiceNo')
frequency
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...          ...       ...                                  ...       ...
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Total
# ...

# %%
#frequency
frequency= frequency.groupby(['CustomerID']).count()[['InvoiceNo']]
#frequency = frequency.groupby('CustomerID')['InvoiceNo'].count().reset_index()
#frequency.rename(columns={'InvoiceNo': 'InvoiceCount'}, inplace=True)
#frequency = frequency.reset_index(drop=True)
#frequency = frequency.sort_values(by='InvoiceCount', ascending=False)
frequency
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4372 rows x 1 columns]

# %%
#monetary
df['Total']= df['Quantity']*df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Total
# ...

# %%
money = df.groupby(['CustomerID'])[['Total']].count()
money
# Out:
#             Total
# CustomerID
# 12346.0         2
# 12347.0       182
# 12348.0        31
# 12349.0        73
# 12350.0        17
# ...           ...
# 18280.0        10
# 18281.0         7
# 18282.0        13
# 18283.0       756
# 18287.0        70
#
# [4372 rows x 1 columns]

# %%
RFM=pd.concat([recency,frequency,money], axis=1)
RFM
# Out:
#             InvoiceAge  InvoiceNo  Total
# CustomerID
# 12346.0            347          2      2
# 12347.0             24          7    182
# 12348.0             97          4     31
# 12349.0             40          1     73
# 12350.0            332          1     17
# ...                ...        ...    ...
# 18280.0            299          1     10
# 18281.0            202          1      7
# 18282.0             29          3     13
# 18283.0             25         16    756
# 18287.0             64          3     70
#
# [4372 rows x 3 columns]

# %%
RFM.columns=['Recency', 'Frequency', 'Monetary']
RFM
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         347          2         2
# 12347.0          24          7       182
# 12348.0          97          4        31
# 12349.0          40          1        73
# 12350.0         332          1        17
# ...             ...        ...       ...
# 18280.0         299          1        10
# 18281.0         202          1         7
# 18282.0          29          3        13
# 18283.0          25         16       756
# 18287.0          64          3        70
#
# [4372 rows x 3 columns]
